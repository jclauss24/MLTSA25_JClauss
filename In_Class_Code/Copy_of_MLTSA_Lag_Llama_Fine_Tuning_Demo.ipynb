# %% [markdown]
# <a href="https://colab.research.google.com/github/jclauss24/MLTSA25_JClauss/blob/main/In_Class_Code/Copy_of_MLTSA_Lag_Llama_Fine_Tuning_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Lag-Llama Fine Tuning MLTSA
#
# ## Prepare the repository
#
# We first clone and install the required packages from the [GitHub repository](https://github.com/time-series-foundation-models/lag-llama/) that has the Lag-Llama architecture.

# %%
# !git clone -b update-gluonts https://github.com/time-series-foundation-models/lag-llama/
# Out:
# Cloning into 'lag-llama'...
# remote: Enumerating objects: 505, done.
# remote: Counting objects: 100% (193/193), done.
# remote: Compressing objects: 100% (84/84), done.
# remote: Total 505 (delta 154), reused 109 (delta 109), pack-reused 312 (from 3)
# Receiving objects: 100% (505/505), 283.34 KiB | 418.00 KiB/s, done.
# Resolving deltas: 100% (252/252), done.

# %%
cd /content/lag-llama
# Out:
# /content/lag-llama

# %%
# !pip uninstall jax jaxlib tensorboard -y
# Out:
# Found existing installation: jax 0.5.2
# Uninstalling jax-0.5.2:
#   Successfully uninstalled jax-0.5.2
# Found existing installation: jaxlib 0.5.1
# Uninstalling jaxlib-0.5.1:
#   Successfully uninstalled jaxlib-0.5.1
# Found existing installation: tensorboard 2.18.0
# Uninstalling tensorboard-2.18.0:
#   Successfully uninstalled tensorboard-2.18.0

# %%
# !pip install -U -r requirements.txt --quiet
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.7/67.7 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 73.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 811.0/811.0 kB 47.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 34.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 96.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 31.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 102.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 66.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.2/484.2 kB 34.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 961.5/961.5 kB 56.7 MB/s eta 0:00:00

# %% [markdown]
# We then download our pretrained model weights from [HuggingFace](https://huggingface.co/time-series-foundation-models/Lag-Llama) 🤗

# %%
# !huggingface-cli download time-series-foundation-models/Lag-Llama lag-llama.ckpt --local-dir /content/lag-llama
# Out:
# Downloading 'lag-llama.ckpt' to '/content/lag-llama/.cache/huggingface/download/59Iq1KnnyJzBevZl6u7vR_lVuAs=.b5a5c4b8a0cfe9b81bdac35ed5d88b5033cd119b5206c28e9cd67c4b45fb2c96.incomplete'
# lag-llama.ckpt: 100% 29.5M/29.5M [00:00<00:00, 227MB/s]
# Download complete. Moving file to /content/lag-llama/lag-llama.ckpt
# /content/lag-llama/lag-llama.ckpt

# %% [markdown]
# ## Imports
#
# We import the required packages and the lag llama estimator object which we can use to make predictions.

# %%
from itertools import islice

import pandas as pd
from matplotlib import pyplot as plt
import matplotlib.dates as mdates
from tqdm.autonotebook import tqdm
import glob
import numpy as np

from scipy.signal import butter, lfilter

import torch

from lag_llama.gluon.estimator import LagLlamaEstimator # this is what will run the prediction

import sys
from types import ModuleType

from gluonts.evaluation import make_evaluation_predictions, MultivariateEvaluator
from gluonts.evaluation import Evaluator # this is a time series specific function
# Out:
# <ipython-input-6-b6a62eef4d70>:6: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
# Create dummy module hierarchy
def create_dummy_module(module_path):
    """
    Create a dummy module hierarchy for the given path.
    Returns the leaf module.
    """
    parts = module_path.split('.')
    current = ''
    parent = None

    for part in parts:
        current = current + '.' + part if current else part
        if current not in sys.modules:
            module = ModuleType(current)
            sys.modules[current] = module
            if parent:
                setattr(sys.modules[parent], part, module)
        parent = current

    return sys.modules[module_path]

# Create the dummy gluonts module hierarchy
gluonts_module = create_dummy_module('gluonts.torch.modules.loss')

# Create dummy classes for the specific loss functions
class DistributionLoss:
    def __init__(self, *args, **kwargs):
        pass

    def __call__(self, *args, **kwargs):
        return 0.0

    def __getattr__(self, name):
        return lambda *args, **kwargs: None

class NegativeLogLikelihood:
    def __init__(self, *args, **kwargs):
        pass

    def __call__(self, *args, **kwargs):
        return 0.0

    def __getattr__(self, name):
        return lambda *args, **kwargs: None

# Add the specific classes to the module
gluonts_module.DistributionLoss = DistributionLoss
gluonts_module.NegativeLogLikelihood = NegativeLogLikelihood

# %% [markdown]
# We create a function for Lag-Llama inference that we can reuse. This function returns the predictions for the given prediction horizon. The forecast will be of shape (num_samples, prediction_length), where `num_samples` is the number of samples sampled from the predicted probability distribution for each timestep.

# %%
def get_lag_llama_predictions(dataset, prediction_length, context_length=32,
              num_samples=20, device="cuda", batch_size=64, nonnegative_pred_samples=True):
    ckpt = torch.load("lag-llama.ckpt", map_location=device, weights_only=False) # modified
    estimator_args = ckpt["hyper_parameters"]["model_kwargs"] # extract hyperparameters

    estimator = LagLlamaEstimator(
        ckpt_path="lag-llama.ckpt",
        prediction_length=prediction_length, # number of time series i am going to predict
        context_length=context_length, # amount that you will look back at to use to predict

        # estimator args
        input_size=estimator_args["input_size"],
        n_layer=estimator_args["n_layer"],
        n_embd_per_head=estimator_args["n_embd_per_head"],
        n_head=estimator_args["n_head"],
        scaling=estimator_args["scaling"],
        time_feat=estimator_args["time_feat"],

        nonnegative_pred_samples=nonnegative_pred_samples,

        # linear positional encoding scaling
        rope_scaling={
            "type": "linear",
            "factor": max(1.0, (context_length + prediction_length) / estimator_args["context_length"]),
        },

        batch_size=batch_size,
        num_parallel_samples=num_samples,
    )

    lightning_module = estimator.create_lightning_module()
    transformation = estimator.create_transformation()
    predictor = estimator.create_predictor(transformation, lightning_module)

    forecast_it, ts_it = make_evaluation_predictions(
        dataset=dataset,
        predictor=predictor,
        num_samples=num_samples
    )
    forecasts = list(tqdm(forecast_it, total=len(dataset), desc="Forecasting batches"))
    tss = list(tqdm(ts_it, total=len(dataset), desc="Ground truth"))

    return forecasts, tss

# %% [markdown]
# # Zero Shot

# %% [markdown]
# ## data : `M4-Weekly`

# %%
from gluonts.dataset.repository import get_dataset
dataset = get_dataset("m4_weekly")
train_dataset = dataset.train
test_dataset = dataset.test

# %%
print(f"dataset length: {len(test_dataset)}")
# Out:
# dataset length: 359

# %%
prediction_length = dataset.metadata.prediction_length
context_length = prediction_length * 3
num_samples = 20
device = "cuda"
print(f"prediction_length {prediction_length}")
# Out:
# prediction_length 13

# %% [markdown]
# ## NEW DATASET

# %%
# @title
# !git clone https://github.com/nlandolfi/acc2022treelinearcascades_stocks.git
# Out:
# fatal: destination path 'acc2022treelinearcascades_stocks' already exists and is not an empty directory.

# %%
# @title
files = glob.glob("acc2022treelinearcascades_stocks/data/*")
files
# Out:
# ['acc2022treelinearcascades_stocks/data/cat.csv',
#  'acc2022treelinearcascades_stocks/data/crm.csv',
#  'acc2022treelinearcascades_stocks/data/msft.csv',
#  'acc2022treelinearcascades_stocks/data/gs.csv',
#  'acc2022treelinearcascades_stocks/data/ba.csv',
#  'acc2022treelinearcascades_stocks/data/dow.csv',
#  'acc2022treelinearcascades_stocks/data/csco.csv',
#  'acc2022treelinearcascades_stocks/data/unh.csv',
#  'acc2022treelinearcascades_stocks/data/amgn.csv',
#  'acc2022treelinearcascades_stocks/data/ko.csv',
#  'acc2022treelinearcascades_stocks/data/wba.csv',
#  'acc2022treelinearcascades_stocks/data/intc.csv',
#  'acc2022treelinearcascades_stocks/data/mmm.csv',
#  'acc2022treelinearcascades_stocks/data/axp.csv',
#  'acc2022treelinearcascades_stocks/data/jpm.csv',
#  'acc2022treelinearcascades_stocks/data/pg.csv',
#  'acc2022treelinearcascades_stocks/data/vz.csv',
#  'acc2022treelinearcascades_stocks/data/cvx.csv',
#  'acc2022treelinearcascades_stocks/data/mcd.csv',
#  'acc2022treelinearcascades_stocks/data/wmt.csv',
#  'acc2022treelinearcascades_stocks/data/aapl.csv',
#  'acc2022treelinearcascades_stocks/data/trv.csv',
#  'acc2022treelinearcascades_stocks/data/jnj.csv',
#  'acc2022treelinearcascades_stocks/data/v.csv',
#  'acc2022treelinearcascades_stocks/data/dis.csv',
#  'acc2022treelinearcascades_stocks/data/ibm.csv',
#  'acc2022treelinearcascades_stocks/data/mrk.csv',
#  'acc2022treelinearcascades_stocks/data/hd.csv',
#  'acc2022treelinearcascades_stocks/data/hon.csv',
#  'acc2022treelinearcascades_stocks/data/nke.csv']

# %%
# @title
pd.read_csv(files[0], index_col=0)
# Out:
#             Open      High       Low   Close    Volume
# Date
# 05/12/21  241.27  243.2300  236.4447  237.32   3668456
# 05/11/21  238.78  242.9899  236.5400  239.30   3163104
# 05/10/21  243.50  245.7800  242.5900  242.61   3752901
# 05/07/21  235.64  241.8900  233.1600  240.99   3327927
# 05/06/21  238.00  240.9828  236.0000  237.07   4526952
# ...          ...       ...       ...     ...       ...
# 05/19/11  106.61  106.8700  104.9100  105.30   8618525
# 05/18/11  102.85  105.5000  101.7800  105.25   9472870
# 05/17/11  105.08  105.2300  101.4700  102.08  19233160
# 05/16/11  105.87  108.2700  105.0700  106.09   8292202
# 05/13/11  109.47  109.6000  106.0200  106.33   9253089
#
# [2516 rows x 5 columns]

# %%
# @title
data = np.zeros((len(files)-1,  pd.read_csv(files[0], index_col=0).shape[0])) #prep data array for all files

# %%
# @title
j = 0
for i,f in enumerate(files):
  _ = pd.read_csv(f, index_col=0)
  if len(_) < data.shape[1]:
    continue

  data[j, :len(_[' Volume'])] = _[' Volume'].values
  j += 1
data.shape
# Out:
# (29, 2516)

# %%
# @title
x = pd.to_datetime(_.index)
fig, ax = plt.subplots(3,3, figsize=(20,10), sharex=True)
for i in range(9):
  ax[i%3, i//3].plot(x, data[i])
  if i%3 > 1:
    ax[i%3, i//3].set_xticklabels(labels=ax[i%3, i//3].get_xticklabels(), rotation=45)
plt.show()
# Out:
# <ipython-input-35-9c8ca7df8c06>:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   x = pd.to_datetime(_.index)
# <ipython-input-35-9c8ca7df8c06>:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i%3, i//3].set_xticklabels(labels=ax[i%3, i//3].get_xticklabels(), rotation=45)
# <ipython-input-35-9c8ca7df8c06>:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i%3, i//3].set_xticklabels(labels=ax[i%3, i//3].get_xticklabels(), rotation=45)
# <ipython-input-35-9c8ca7df8c06>:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i%3, i//3].set_xticklabels(labels=ax[i%3, i//3].get_xticklabels(), rotation=45)

# %%
# @title
x.diff()
# Out:
# TimedeltaIndex([      NaT, '-1 days', '-1 days', '-3 days', '-1 days',
#                 '-1 days', '-1 days', '-1 days', '-3 days', '-1 days',
#                 ...
#                 '-1 days', '-1 days', '-1 days', '-1 days', '-3 days',
#                 '-1 days', '-1 days', '-1 days', '-1 days', '-3 days'],
#                dtype='timedelta64[ns]', name='Date', length=2516, freq=None)

# %%
# @title
df = pd.DataFrame(data=data).T
df.index= pd.to_datetime(x, format="%m/%d/%y")
df_resampled = df.resample('2d').mean()#.fillna(df.mean())
df_resampled = df_resampled.interpolate(limit_direction='both')
df_resampled.index.diff().unique()
# Out:
# TimedeltaIndex([NaT, '2 days'], dtype='timedelta64[ns]', name='Date', freq=None)

# %%
# @title
df_resampled.shape
# Out:
# (1827, 29)

# %%
# @title
x = df_resampled.index
fig, ax = plt.subplots(3,3, figsize=(20,10), sharex=True)
for i in range(9):
  ax[i%3, i//3].plot(x, df_resampled.iloc[:,i])
  if i%3 > 1:
    ax[i%3, i//3].set_xticklabels(labels=ax[i%3, i//3].get_xticklabels(), rotation=45)
plt.show()
# Out:
# <ipython-input-39-f56858e44453>:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i%3, i//3].set_xticklabels(labels=ax[i%3, i//3].get_xticklabels(), rotation=45)
# <ipython-input-39-f56858e44453>:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i%3, i//3].set_xticklabels(labels=ax[i%3, i//3].get_xticklabels(), rotation=45)
# <ipython-input-39-f56858e44453>:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i%3, i//3].set_xticklabels(labels=ax[i%3, i//3].get_xticklabels(), rotation=45)

# %%
# @title
# prompt: lowpass filter the imput data
from scipy.signal import butter, lfilter, filtfilt


def butter_lowpass(cutoff, fs, order=5):
    """
    Design a digital Butterworth low-pass filter.

    The Butterworth filter is characterized by a maximally flat magnitude response
    in the passband and a monotonic roll-off in the stopband.  This function
    calculates the filter coefficients for a low-pass Butterworth filter.

    Args:
        cutoff (float): The cutoff frequency of the filter in Hz.  This is the
            frequency at which the filter's gain is reduced by 3 dB (half-power).
        fs (float): The sampling rate of the signal to be filtered, in Hz.
        order (int, optional): The order of the filter.  Higher order filters
            provide a steeper roll-off but also increase the filter's complexity
            and introduce more phase delay.  The default is 5.

    Returns:
        tuple: A tuple of two NumPy arrays, (b, a).
            - b (ndarray): The numerator coefficients of the filter's transfer function.
            - a (ndarray): The denominator coefficients of the filter's transfer function.

    The filter's transfer function is defined as:
    ∣H(jω)∣^2 = 1 / (1 + (ω/ωc)^(2n))

    Where:
    - ω is the angular frequency (2 * pi * frequency)
    - ωc is the cutoff angular frequency (2 * pi * cutoff)
    - n is the filter order
    """

    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='low', analog=False)
    return b, a

def butter_lowpass_filter(data, cutoff, fs, order=5):
    """
    Apply a digital Butterworth low-pass filter to input data.

    This function designs and applies a Butterworth low-pass filter to the given
    input data using forward-backward filtering to minimize phase distortion.

    Args:
        data (ndarray): The input data to be filtered.  It should be a 1-D NumPy array.
        cutoff (float): The cutoff frequency of the filter in Hz.
            Frequencies above this will be attenuated.
        fs (float): The sampling rate of the input data, in Hz.
        order (int, optional): The order of the filter. Higher order filters
            provide a steeper roll-off but can increase complexity. The default is 5.

    Returns:
        ndarray: The filtered data, with the same shape as the input data.

    """
    b, a = butter_lowpass(cutoff, fs, order=order)
    y = filtfilt(b, a, data)
    return y

fs = 1/48  # Replace with your actual sampling frequency this is in hours

# Choose cutoff frequency (adjust based on desired filtering characteristics)
cutoff = 1/48/50

# Apply filter to each time series in 'data'
filtered_data = np.zeros_like(df_resampled.T.values)
for i in range(filtered_data.shape[0]):
    filtered_data[i, :] = butter_lowpass_filter(df_resampled.iloc[:,i], cutoff, fs, order=5)

# Now 'filtered_data' contains the low-pass filtered time series data
# You can proceed to plot or further analyze the filtered data

fig, ax = plt.subplots(3,3, figsize=(20,10), sharex=True)
for i in range(9):
  ax[i%3, i//3].plot(x, df_resampled.iloc[:,i])
  ax[i%3, i//3].plot(x, filtered_data[i], 'r')
  if i%3 > 1:
    ax[i%3, i//3].set_xticklabels(labels=ax[i%3, i//3].get_xticklabels(), rotation=45)
plt.show()
# Out:
# <ipython-input-40-582f5e3bb960>:82: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i%3, i//3].set_xticklabels(labels=ax[i%3, i//3].get_xticklabels(), rotation=45)
# <ipython-input-40-582f5e3bb960>:82: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i%3, i//3].set_xticklabels(labels=ax[i%3, i//3].get_xticklabels(), rotation=45)
# <ipython-input-40-582f5e3bb960>:82: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax[i%3, i//3].set_xticklabels(labels=ax[i%3, i//3].get_xticklabels(), rotation=45)

# %%
# @title
df_filtered = pd.DataFrame(data=filtered_data).T
df_filtered.index = x
df_filtered.index.diff().unique(),
# Out:
# (TimedeltaIndex([NaT, '2 days'], dtype='timedelta64[ns]', name='Date', freq=None),)

# %%
# @title
df_filtered
# Out:
#                       0             1             2             3   \
# Date
# 2011-05-13  8.995213e+06  5.670782e+06  6.578553e+07  1.412484e+07
# 2011-05-15  8.884250e+06  5.986276e+06  6.477792e+07  1.343333e+07
# 2011-05-17  8.775159e+06  6.290164e+06  6.378855e+07  1.274603e+07
# 2011-05-19  8.669218e+06  6.580236e+06  6.282768e+07  1.206700e+07
# 2011-05-21  8.567720e+06  6.854517e+06  6.190545e+07  1.140026e+07
# ...                  ...           ...           ...           ...
# 2021-05-04  2.980731e+06  5.456390e+06  2.966824e+07  3.036127e+06
# 2021-05-06  2.976675e+06  5.425610e+06  2.968591e+07  3.039945e+06
# 2021-05-08  2.973472e+06  5.399262e+06  2.970316e+07  3.043327e+06
# 2021-05-10  2.970999e+06  5.377023e+06  2.971960e+07  3.046281e+06
# 2021-05-12  2.969135e+06  5.358536e+06  2.973490e+07  3.048822e+06
#
#                       4             5             6             7   \
# Date
# 2011-05-13  3.663073e+06  8.061302e+07  1.101535e+07  9.259940e+06
# 2011-05-15  3.681548e+06  7.970308e+07  1.072445e+07  8.873024e+06
# 2011-05-17  3.700479e+06  7.877636e+07  1.043194e+07  8.489529e+06
# 2011-05-19  3.720320e+06  7.783991e+07  1.014015e+07  8.112228e+06
# 2011-05-21  3.741555e+06  7.690102e+07  9.851391e+06  7.743868e+06
# ...                  ...           ...           ...           ...
# 2021-05-04  1.477832e+07  2.014648e+07  2.794049e+06  2.668111e+06
# 2021-05-06  1.468681e+07  2.008585e+07  2.785486e+06  2.662055e+06
# 2021-05-08  1.460809e+07  2.003454e+07  2.778268e+06  2.656777e+06
# 2021-05-10  1.454135e+07  1.999174e+07  2.772266e+06  2.652239e+06
# 2021-05-12  1.448565e+07  1.995661e+07  2.767350e+06  2.648393e+06
#
#                       8             9   ...            19            20  \
# Date                                    ...
# 2011-05-13  1.585729e+07  6.133773e+06  ...  3.162255e+08  4.033577e+06
# 2011-05-15  1.568664e+07  6.201335e+06  ...  3.223338e+08  3.973407e+06
# 2011-05-17  1.551712e+07  6.261419e+06  ...  3.283127e+08  3.911882e+06
# 2011-05-19  1.535102e+07  6.314861e+06  ...  3.341923e+08  3.849760e+06
# 2011-05-21  1.519071e+07  6.362550e+06  ...  3.400055e+08  3.787827e+06
# ...                  ...           ...  ...           ...           ...
# 2021-05-04  1.487515e+07  5.564981e+06  ...  9.730569e+07  1.393112e+06
# 2021-05-06  1.482804e+07  5.555218e+06  ...  9.720886e+07  1.390849e+06
# 2021-05-08  1.478801e+07  5.546701e+06  ...  9.713098e+07  1.388870e+06
# 2021-05-10  1.475449e+07  5.539384e+06  ...  9.706960e+07  1.387168e+06
# 2021-05-12  1.472684e+07  5.533199e+06  ...  9.702229e+07  1.385726e+06
#
#                       21            22            23            24  \
# Date
# 2011-05-13  1.136637e+07  2.190934e+07  8.023799e+06  5.021691e+06
# 2011-05-15  1.123440e+07  2.234309e+07  8.112894e+06  4.984632e+06
# 2011-05-17  1.109976e+07  2.279489e+07  8.202416e+06  4.947945e+06
# 2011-05-19  1.096405e+07  2.326219e+07  8.292746e+06  4.912269e+06
# 2011-05-21  1.082899e+07  2.374216e+07  8.384374e+06  4.878262e+06
# ...                  ...           ...           ...           ...
# 2021-05-04  7.441539e+06  7.656132e+06  8.001511e+06  5.474844e+06
# 2021-05-06  7.437000e+06  7.624426e+06  7.939605e+06  5.488886e+06
# 2021-05-08  7.433030e+06  7.597570e+06  7.887246e+06  5.501438e+06
# 2021-05-10  7.429593e+06  7.575125e+06  7.843579e+06  5.512462e+06
# 2021-05-12  7.426654e+06  7.556637e+06  7.807707e+06  5.521970e+06
#
#                       25            26            27            28
# Date
# 2011-05-13  1.113300e+07  8.616866e+06  3.503001e+06  1.453246e+07
# 2011-05-15  1.106339e+07  8.778116e+06  3.471073e+06  1.427465e+07
# 2011-05-17  1.099613e+07  8.931608e+06  3.439817e+06  1.403093e+07
# 2011-05-19  1.093248e+07  9.077582e+06  3.410001e+06  1.380304e+07
# 2011-05-21  1.087376e+07  9.216435e+06  3.382437e+06  1.359253e+07
# ...                  ...           ...           ...           ...
# 2021-05-04  1.208384e+07  4.771561e+06  3.145055e+06  7.302205e+06
# 2021-05-06  1.205517e+07  4.761212e+06  3.149870e+06  7.283732e+06
# 2021-05-08  1.203075e+07  4.752565e+06  3.154274e+06  7.267182e+06
# 2021-05-10  1.201025e+07  4.745467e+06  3.158244e+06  7.252594e+06
# 2021-05-12  1.199331e+07  4.739749e+06  3.161768e+06  7.239953e+06
#
# [1827 rows x 29 columns]

# %%
# @title
#we are not going to use it but useful cause it may be inputts in gluonts: how do i make it a single column df?
df_filtered_long = df_filtered.reset_index()
df_filtered_long = df_filtered_long.melt(id_vars="Date")
df_filtered_long.set_index("Date", inplace=True)
df_filtered_long.index = pd.to_datetime(df_filtered_long.index)
df_filtered_long
# Out:
#            variable         value
# Date
# 2011-05-13        0  8.995213e+06
# 2011-05-15        0  8.884250e+06
# 2011-05-17        0  8.775159e+06
# 2011-05-19        0  8.669218e+06
# 2011-05-21        0  8.567720e+06
# ...             ...           ...
# 2021-05-04       28  7.302205e+06
# 2021-05-06       28  7.283732e+06
# 2021-05-08       28  7.267182e+06
# 2021-05-10       28  7.252594e+06
# 2021-05-12       28  7.239953e+06
#
# [52983 rows x 2 columns]

# %%
# @title
ax = df_filtered.plot(legend=False)
ax.set_xticklabels(labels=ax.get_xticklabels(), rotation=90);
# Out:
# <ipython-input-44-bd51323524e0>:3: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(labels=ax.get_xticklabels(), rotation=90);

# %%
# @title
df_filtered.isna().sum().sum()
# Out:
# np.int64(0)

# %%
# @title
#import into gluonts
from gluonts.dataset.field_names import FieldName
from gluonts.dataset.common import ListDataset

start_date = df_filtered.index[0]
train_data = []
test_data = []
for i in range(len(df_filtered.columns)):
    # Create synthetic time series with some dependencies
    target = df_filtered.iloc[:,i]

    train_target = target[:-prediction_length]
    test_target = target

    train_data.append({
        FieldName.TARGET: train_target,
        FieldName.START: start_date,
        FieldName.ITEM_ID: f"series_{i}"
    })
    test_data.append({
        FieldName.TARGET: test_target,
        FieldName.START: start_date,
        FieldName.ITEM_ID: f"series_{i}"
    })

# Convert to GluonTS ListDataset
train_dataset = ListDataset(train_data, freq="2d")
test_dataset = ListDataset(test_data, freq="2d")

# %% [markdown]
# ## predict

# %%
list(train_dataset)[0]
# Out:
# {'target': array([8995213. , 8884250. , 8775159. , ..., 3112683.2, 3092871. ,
#         3074652.5], dtype=float32),
#  'start': Period('2011-05-13', '2D'),
#  'item_id': 'series_0'}

# %%
plt.plot(list(train_dataset)[0]["target"])

# %%
forecasts, tss = get_lag_llama_predictions(
    test_dataset,
    prediction_length=prediction_length,
    num_samples=num_samples,
    context_length=context_length,
    device=device
)
# Out:
# Forecasting batches:   0%|          | 0/29 [00:00<?, ?it/s]
# Ground truth:   0%|          | 0/29 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(20, 15))
date_formater = mdates.DateFormatter('%b, %d')
plt.rcParams.update({'font.size': 15})

# Iterate through the first 9 series, and plot the predicted samples
for idx, (forecast, ts) in islice(enumerate(zip(forecasts, tss)), 9):
    ax = plt.subplot(3, 3, idx+1)

    plt.plot(ts[-25 * prediction_length:].to_timestamp(), label="target", )
    forecast.plot( color='g')
    plt.xticks(rotation=60)
    ax.xaxis.set_major_formatter(date_formater)
    ax.set_title(forecast.item_id)

plt.gcf().tight_layout()
plt.legend()
plt.show()

# %% [markdown]
# # Fine-tuning
#
# Let us fine-tune the Lag-Llama base model with a few data-specific changes. Feel Free to change the hyperparameters below:

# %%
ckpt = torch.load("lag-llama.ckpt", map_location=device, weights_only=False)
estimator_args = ckpt["hyper_parameters"]["model_kwargs"]

estimator = LagLlamaEstimator(
        ckpt_path="lag-llama.ckpt",
        prediction_length=prediction_length,
        context_length=context_length,

        # distr_output="neg_bin",
        # scaling="mean",
        nonnegative_pred_samples=True,
        aug_prob=0,
        #lr=5e-4,
        lr=5e-6,

        # estimator args
        input_size=estimator_args["input_size"],
        n_layer=estimator_args["n_layer"],
        n_embd_per_head=estimator_args["n_embd_per_head"],
        n_head=estimator_args["n_head"],
        time_feat=estimator_args["time_feat"],

        # rope_scaling={
        #     "type": "linear",
        #     "factor": max(1.0, (context_length + prediction_length) / estimator_args["context_length"]),
        # },

        batch_size=64,
        num_parallel_samples=num_samples,
        trainer_kwargs = {"max_epochs": 50,}, # <- lightning trainer arguments
    )

# %%
predictor = estimator.train(train_dataset,
    cache_data=True, shuffle_buffer_length=1000)
# Out:
# INFO: GPU available: True (cuda), used: True
# INFO:lightning.pytorch.utilities.rank_zero:GPU available: True (cuda), used: True
# INFO: TPU available: False, using: 0 TPU cores
# INFO:lightning.pytorch.utilities.rank_zero:TPU available: False, using: 0 TPU cores
# INFO: HPU available: False, using: 0 HPUs
# INFO:lightning.pytorch.utilities.rank_zero:HPU available: False, using: 0 HPUs
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/configuration_validator.py:70: You defined a `validation_step` but have no `val_dataloader`. Skipping val loop.
# INFO: LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:lightning.pytorch.accelerators.cuda:LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# INFO:
#   | Name          | Type               | Params | Mode
# -------------------------------------------------------------
# 0 | model         | LagLlamaModel      | 2.4 M  | train
# 1 | augmentations | ApplyAugmentations | 0      | train
# -------------------------------------------------------------
# 2.4 M     Trainable params
# 0         Non-trainable params
# 2.4 M     Total params
# 9.797     Total estimated model params size (MB)
# 110       Modules in train mode
# 0         Modules in eval mode
# INFO:lightning.pytorch.callbacks.model_summary:
#   | Name          | Type               | Params | Mode
# -------------------------------------------------------------
# 0 | model         | LagLlamaModel      | 2.4 M  | train
# 1 | augmentations | ApplyAugmentations | 0      | train
# -------------------------------------------------------------
# 2.4 M     Trainable params
# 0         Non-trainable params
# 2.4 M     Total params
# 9.797     Total estimated model params size (MB)
# 110       Modules in train mode
# 0         Modules in eval mode
# Training: |          | 0/? [00:00<?, ?it/s]
# INFO: Epoch 0, global step 50: 'train_loss' reached 14.01893 (best 14.01893), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=0-step=50.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 0, global step 50: 'train_loss' reached 14.01893 (best 14.01893), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=0-step=50.ckpt' as top 1
# INFO: Epoch 1, global step 100: 'train_loss' reached 12.91170 (best 12.91170), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=1-step=100.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 1, global step 100: 'train_loss' reached 12.91170 (best 12.91170), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=1-step=100.ckpt' as top 1
# INFO: Epoch 2, global step 150: 'train_loss' reached 12.51273 (best 12.51273), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=2-step=150.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 2, global step 150: 'train_loss' reached 12.51273 (best 12.51273), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=2-step=150.ckpt' as top 1
# INFO: Epoch 3, global step 200: 'train_loss' reached 12.30937 (best 12.30937), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=3-step=200.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 3, global step 200: 'train_loss' reached 12.30937 (best 12.30937), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=3-step=200.ckpt' as top 1
# INFO: Epoch 4, global step 250: 'train_loss' reached 12.09869 (best 12.09869), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=4-step=250.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 4, global step 250: 'train_loss' reached 12.09869 (best 12.09869), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=4-step=250.ckpt' as top 1
# INFO: Epoch 5, global step 300: 'train_loss' reached 12.01282 (best 12.01282), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=5-step=300.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 5, global step 300: 'train_loss' reached 12.01282 (best 12.01282), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=5-step=300.ckpt' as top 1
# INFO: Epoch 6, global step 350: 'train_loss' reached 11.90078 (best 11.90078), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=6-step=350.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 6, global step 350: 'train_loss' reached 11.90078 (best 11.90078), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=6-step=350.ckpt' as top 1
# INFO: Epoch 7, global step 400: 'train_loss' reached 11.82901 (best 11.82901), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=7-step=400.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 7, global step 400: 'train_loss' reached 11.82901 (best 11.82901), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=7-step=400.ckpt' as top 1
# INFO: Epoch 8, global step 450: 'train_loss' reached 11.76990 (best 11.76990), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=8-step=450.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 8, global step 450: 'train_loss' reached 11.76990 (best 11.76990), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=8-step=450.ckpt' as top 1
# INFO: Epoch 9, global step 500: 'train_loss' reached 11.70379 (best 11.70379), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=9-step=500.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 9, global step 500: 'train_loss' reached 11.70379 (best 11.70379), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=9-step=500.ckpt' as top 1
# INFO: Epoch 10, global step 550: 'train_loss' reached 11.65146 (best 11.65146), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=10-step=550.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 10, global step 550: 'train_loss' reached 11.65146 (best 11.65146), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=10-step=550.ckpt' as top 1
# INFO: Epoch 11, global step 600: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 11, global step 600: 'train_loss' was not in top 1
# INFO: Epoch 12, global step 650: 'train_loss' reached 11.60065 (best 11.60065), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=12-step=650.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 12, global step 650: 'train_loss' reached 11.60065 (best 11.60065), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=12-step=650.ckpt' as top 1
# INFO: Epoch 13, global step 700: 'train_loss' reached 11.57358 (best 11.57358), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=13-step=700.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 13, global step 700: 'train_loss' reached 11.57358 (best 11.57358), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=13-step=700.ckpt' as top 1
# INFO: Epoch 14, global step 750: 'train_loss' reached 11.46819 (best 11.46819), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=14-step=750.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 14, global step 750: 'train_loss' reached 11.46819 (best 11.46819), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=14-step=750.ckpt' as top 1
# INFO: Epoch 15, global step 800: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 15, global step 800: 'train_loss' was not in top 1
# INFO: Epoch 16, global step 850: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 16, global step 850: 'train_loss' was not in top 1
# INFO: Epoch 17, global step 900: 'train_loss' reached 11.41131 (best 11.41131), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=17-step=900.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 17, global step 900: 'train_loss' reached 11.41131 (best 11.41131), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=17-step=900.ckpt' as top 1
# INFO: Epoch 18, global step 950: 'train_loss' reached 11.39318 (best 11.39318), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=18-step=950.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 18, global step 950: 'train_loss' reached 11.39318 (best 11.39318), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=18-step=950.ckpt' as top 1
# INFO: Epoch 19, global step 1000: 'train_loss' reached 11.36126 (best 11.36126), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=19-step=1000.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 19, global step 1000: 'train_loss' reached 11.36126 (best 11.36126), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=19-step=1000.ckpt' as top 1
# INFO: Epoch 20, global step 1050: 'train_loss' was not in top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 20, global step 1050: 'train_loss' was not in top 1
# INFO: Epoch 21, global step 1100: 'train_loss' reached 11.33967 (best 11.33967), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=21-step=1100.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 21, global step 1100: 'train_loss' reached 11.33967 (best 11.33967), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=21-step=1100.ckpt' as top 1
# INFO: Epoch 22, global step 1150: 'train_loss' reached 11.29631 (best 11.29631), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=22-step=1150.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 22, global step 1150: 'train_loss' reached 11.29631 (best 11.29631), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=22-step=1150.ckpt' as top 1
# INFO: Epoch 23, global step 1200: 'train_loss' reached 11.27311 (best 11.27311), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=23-step=1200.ckpt' as top 1
# INFO:lightning.pytorch.utilities.rank_zero:Epoch 23, global step 1200: 'train_loss' reached 11.27311 (best 11.27311), saving model to '/content/lag-llama/lightning_logs/version_2/checkpoints/epoch=23-step=1200.ckpt' as top 1
# INFO:
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# INFO:lightning.pytorch.utilities.rank_zero:
# Detected KeyboardInterrupt, attempting graceful shutdown ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      46             return trainer.strategy.launcher.launch(trainer_fn, *args, trainer=trainer, **kwargs)
# ---> 47         return trainer_fn(*args, **kwargs)
#      48
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py in _fit_impl(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     573         )
# --> 574         self._run(model, ckpt_path=ckpt_path)
#     575
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py in _run(self, model, ckpt_path)
#     980         # ----------------------------
# --> 981         results = self._run_stage()
#     982
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py in _run_stage(self)
#    1024             with torch.autograd.set_detect_anomaly(self._detect_anomaly):
# -> 1025                 self.fit_loop.run()
#    1026             return None
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py in run(self)
#     204                 self.on_advance_start()
# --> 205                 self.advance()
#     206                 self.on_advance_end()
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/fit_loop.py in advance(self)
#     362             assert self._data_fetcher is not None
# --> 363             self.epoch_loop.run(self._data_fetcher)
#     364
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py in run(self, data_fetcher)
#     139             try:
# --> 140                 self.advance(data_fetcher)
#     141                 self.on_advance_end(data_fetcher)
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/training_epoch_loop.py in advance(self, data_fetcher)
#     249                     # in automatic optimization, there can only be one optimizer
# --> 250                     batch_output = self.automatic_optimization.run(trainer.optimizers[0], batch_idx, kwargs)
#     251                 else:
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/optimization/automatic.py in run(self, optimizer, batch_idx, kwargs)
#     189         else:
# --> 190             self._optimizer_step(batch_idx, closure)
#     191
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/optimization/automatic.py in _optimizer_step(self, batch_idx, train_step_and_backward_closure)
#     267         # model hook
# --> 268         call._call_lightning_module_hook(
#     269             trainer,
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py in _call_lightning_module_hook(trainer, hook_name, pl_module, *args, **kwargs)
#     166     with trainer.profiler.profile(f"[LightningModule]{pl_module.__class__.__name__}.{hook_name}"):
# --> 167         output = fn(*args, **kwargs)
#     168
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/core/module.py in optimizer_step(self, epoch, batch_idx, optimizer, optimizer_closure)
#    1305         """
# -> 1306         optimizer.step(closure=optimizer_closure)
#    1307
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/core/optimizer.py in step(self, closure, **kwargs)
#     152         assert self._strategy is not None
# --> 153         step_output = self._strategy.optimizer_step(self._optimizer, closure, **kwargs)
#     154
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/strategy.py in optimizer_step(self, optimizer, closure, model, **kwargs)
#     237         assert isinstance(model, pl.LightningModule)
# --> 238         return self.precision_plugin.optimizer_step(optimizer, model=model, closure=closure, **kwargs)
#     239
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/plugins/precision/precision.py in optimizer_step(self, optimizer, model, closure, **kwargs)
#     121         closure = partial(self._wrap_closure, model, optimizer, closure)
# --> 122         return optimizer.step(closure=closure, **kwargs)
#     123
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#     492
# --> 493                 out = func(*args, **kwargs)
#     494                 self._optimizer_step_code()
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/optimizer.py in _use_grad(self, *args, **kwargs)
#      90             torch._dynamo.graph_break()
# ---> 91             ret = func(self, *args, **kwargs)
#      92         finally:
#
# /usr/local/lib/python3.11/dist-packages/torch/optim/adam.py in step(self, closure)
#     222             with torch.enable_grad():
# --> 223                 loss = closure()
#     224
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/plugins/precision/precision.py in _wrap_closure(self, model, optimizer, closure)
#     107         """
# --> 108         closure_result = closure()
#     109         self._after_closure(model, optimizer)
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/optimization/automatic.py in __call__(self, *args, **kwargs)
#     143     def __call__(self, *args: Any, **kwargs: Any) -> Optional[Tensor]:
# --> 144         self._result = self.closure(*args, **kwargs)
#     145         return self._result.loss
#
# /usr/local/lib/python3.11/dist-packages/torch/utils/_contextlib.py in decorate_context(*args, **kwargs)
#     115         with ctx_factory():
# --> 116             return func(*args, **kwargs)
#     117
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/optimization/automatic.py in closure(self, *args, **kwargs)
#     128     def closure(self, *args: Any, **kwargs: Any) -> ClosureResult:
# --> 129         step_output = self._step_fn()
#     130
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/loops/optimization/automatic.py in _training_step(self, kwargs)
#     316
# --> 317         training_step_output = call._call_strategy_hook(trainer, "training_step", *kwargs.values())
#     318         self.trainer.strategy.post_training_step()  # unused hook - call anyway for backward compatibility
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py in _call_strategy_hook(trainer, hook_name, *args, **kwargs)
#     318     with trainer.profiler.profile(f"[Strategy]{trainer.strategy.__class__.__name__}.{hook_name}"):
# --> 319         output = fn(*args, **kwargs)
#     320
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/strategies/strategy.py in training_step(self, *args, **kwargs)
#     389                 return self._forward_redirection(self.model, self.lightning_module, "training_step", *args, **kwargs)
# --> 390             return self.lightning_module.training_step(*args, **kwargs)
#     391
#
# /content/lag-llama/lag_llama/gluon/lightning_module.py in training_step(self, batch, batch_idx)
#     434
# --> 435         train_loss_avg = self._compute_loss(batch, return_observed_values=False)
#     436
#
# /content/lag-llama/lag_llama/gluon/lightning_module.py in _compute_loss(self, batch, return_observed_values, aggregate_by, orignal_scale)
#     374         # distr_args is a tuple with two tensors of shape (bsz, context_length+pred_len-1)
# --> 375         distr_args, loc, scale = self.model(
#     376             past_target=past_target,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#
# /content/lag-llama/lag_llama/model/module.py in forward(self, past_target, past_observed_values, past_time_feat, future_time_feat, future_target, use_kv_cache)
#     574         for block in self.transformer.h:
# --> 575             x = block(x, use_kv_cache)
#     576         # (bsz, context_length+(pred_len-1), n_embd_per_head*n_head)
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#
# /content/lag-llama/lag_llama/model/module.py in forward(self, x, use_kv_cache)
#      48     def forward(self, x: torch.Tensor, use_kv_cache: bool) -> torch.Tensor:
# ---> 49         x = x + self.attn(self.rms_1(x), use_kv_cache)
#      50         y = x + self.mlp(self.rms_2(x))
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#
# /content/lag-llama/lag_llama/model/module.py in forward(self, x, use_kv_cache)
#     349         else:
# --> 350             y = F.scaled_dot_product_attention(
#     351                 q, k, v, attn_mask=None, dropout_p=self.dropout, is_causal=True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# <ipython-input-58-1b4c3639bffc> in <cell line: 0>()
# ----> 1 predictor = estimator.train(train_dataset,
#       2     cache_data=True, shuffle_buffer_length=1000)
#
# /usr/local/lib/python3.11/dist-packages/gluonts/torch/model/estimator.py in train(self, training_data, validation_data, shuffle_buffer_length, cache_data, ckpt_path, **kwargs)
#     244         **kwargs,
#     245     ) -> PyTorchPredictor:
# --> 246         return self.train_model(
#     247             training_data,
#     248             validation_data,
#
# /usr/local/lib/python3.11/dist-packages/gluonts/torch/model/estimator.py in train_model(self, training_data, validation_data, from_predictor, shuffle_buffer_length, cache_data, ckpt_path, **kwargs)
#     207         )
#     208
# --> 209         trainer.fit(
#     210             model=training_network,
#     211             train_dataloaders=training_data_loader,
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/trainer.py in fit(self, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path)
#     536         self.state.status = TrainerStatus.RUNNING
#     537         self.training = True
# --> 538         call._call_and_handle_interrupt(
#     539             self, self._fit_impl, model, train_dataloaders, val_dataloaders, datamodule, ckpt_path
#     540         )
#
# /usr/local/lib/python3.11/dist-packages/lightning/pytorch/trainer/call.py in _call_and_handle_interrupt(trainer, trainer_fn, *args, **kwargs)
#      62         if isinstance(launcher, _SubprocessScriptLauncher):
#      63             launcher.kill(_get_sigkill_signal())
# ---> 64         exit(1)
#      65
#      66     except BaseException as exception:
#
# NameError: name 'exit' is not defined

# %%
forecast_it, ts_it = make_evaluation_predictions(
        test_dataset,
        predictor=predictor,
        num_samples=num_samples
    )

# %%
forecasts = list(tqdm(forecast_it, total=len(test_dataset), desc="Forecasting batches"))
# Out:
# Forecasting batches:   0%|          | 0/29 [00:00<?, ?it/s]

# %%
tss = list(tqdm(ts_it, total=len(test_dataset), desc="Ground truth"))
# Out:
# Ground truth:   0%|          | 0/29 [00:00<?, ?it/s]

# %%
plt.figure(figsize=(20, 15))
date_formater = mdates.DateFormatter('%b, %d')
plt.rcParams.update({'font.size': 15})

# Iterate through the first 9 series, and plot the predicted samples
for idx, (forecast, ts) in islice(enumerate(zip(forecasts, tss)), 9):
    ax = plt.subplot(3, 3, idx+1)

    plt.plot(ts[-25 * prediction_length:].to_timestamp(), label="target", )
    forecast.plot( color='g')
    plt.xticks(rotation=60)
    ax.xaxis.set_major_formatter(date_formater)
    ax.set_title(forecast.item_id)

plt.gcf().tight_layout()
plt.legend()
plt.show()

# %%
evaluator = Evaluator()
agg_metrics, ts_metrics = evaluator(iter(tss), iter(forecasts))
# Out:
# Running evaluation: 359it [00:00, 18956.77it/s]

# %%
agg_metrics
# Out:
# {'MSE': np.float64(772033.0737220988),
#  'abs_error': np.float64(2099597.4081115723),
#  'abs_target_sum': np.float64(25616889.502441406),
#  'abs_target_mean': np.float64(5488.941397566189),
#  'seasonal_error': np.float64(216.54813922503874),
#  'MASE': np.float64(4.892087992972203),
#  'MAPE': np.float64(0.10129428041238),
#  'sMAPE': np.float64(0.10318417743866924),
#  'MSIS': np.float64(44.5420486743558),
#  'num_masked_target_values': np.float64(0.0),
#  'QuantileLoss[0.1]': np.float64(798691.4862976074),
#  'Coverage[0.1]': np.float64(0.169487893721877),
#  'QuantileLoss[0.2]': np.float64(1312729.830541992),
#  'Coverage[0.2]': np.float64(0.28840797085922437),
#  'QuantileLoss[0.3]': np.float64(1693845.1102523801),
#  'Coverage[0.3]': np.float64(0.3923291193486179),
#  'QuantileLoss[0.4]': np.float64(1949917.5075164796),
#  'Coverage[0.4]': np.float64(0.4731090636383115),
#  'QuantileLoss[0.5]': np.float64(2099597.414100647),
#  'Coverage[0.5]': np.float64(0.5403899721448467),
#  'QuantileLoss[0.6]': np.float64(2178420.047784424),
#  'Coverage[0.6]': np.float64(0.5693164773944719),
#  'QuantileLoss[0.7]': np.float64(2091836.713642883),
#  'Coverage[0.7]': np.float64(0.6340261409899294),
#  'QuantileLoss[0.8]': np.float64(1848692.1415252686),
#  'Coverage[0.8]': np.float64(0.7060209985001071),
#  'QuantileLoss[0.9]': np.float64(1394003.094857788),
#  'Coverage[0.9]': np.float64(0.788729376473109),
#  'RMSE': np.float64(878.654126333052),
#  'NRMSE': np.float64(0.16007715562834202),
#  'ND': np.float64(0.0819614500000662),
#  'wQuantileLoss[0.1]': np.float64(0.03117831640806697),
#  'wQuantileLoss[0.2]': np.float64(0.05124470050967284),
#  'wQuantileLoss[0.3]': np.float64(0.0661222007492732),
#  'wQuantileLoss[0.4]': np.float64(0.07611843379074745),
#  'wQuantileLoss[0.5]': np.float64(0.0819614502338602),
#  'wQuantileLoss[0.6]': np.float64(0.08503842933689551),
#  'wQuantileLoss[0.7]': np.float64(0.08165849774397947),
#  'wQuantileLoss[0.8]': np.float64(0.07216692492463145),
#  'wQuantileLoss[0.9]': np.float64(0.05441734425738664),
#  'mean_absolute_QuantileLoss': np.float64(1707525.927391052),
#  'mean_wQuantileLoss': np.float64(0.0666562553282793),
#  'MAE_Coverage': np.float64(0.31596076470728285),
#  'OWA': nan}
